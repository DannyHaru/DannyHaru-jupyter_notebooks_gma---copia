# %%
#%pip install mysql-connector-python pandas
# Out:
# Requirement already satisfied: mysql-connector-python in c:\programdata\miniconda3\lib\site-packages (8.3.0)
# Requirement already satisfied: pandas in c:\programdata\miniconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\programdata\miniconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\miniconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\miniconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\miniconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\programdata\miniconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
# pip install mysql-connector-python pandas

import pymysql
import pandas as pd

# Configura tu conexión a la base de datos
config = {
    'user': 'mantto',
    'password': 'Sistemas0,',
    'host': '192.168.100.50',
    'database': 'opmt2'
}

# Establece la conexión
conn = pymysql.connect(**config)


# Escribe tu consulta SQL
query = "SELECT * FROM anomalias limit 10"


# Ejecuta la consulta y almacena los resultados en un DataFrame
df = pd.read_sql(query, conn)

# Cierra la conexión
conn.close()

# Muestra el DataFrame

df
# Out:
# C:\Users\mantenimiento\AppData\Local\Temp\ipykernel_14908\4117675472.py:23: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#    id_anomalias       ci                      operador  \
# 0             1  6558621        Fabian  Miranda Renjel
# 1             2  6558621  Silvana Edith Tarquino Conde
# 2             3  6558621       Humberto  Aduviri Plata
# 3             4  6558621        William  Quispe Quispe
# 4             5  6558621  Silvana Edith Tarquino Conde
# 5             6  6558621  Silvana Edith Tarquino Conde
# 6             7  6558621  Silvana Edith Tarquino Conde
# 7             8  6558621       Humberto  Aduviri Plata
# 8             9  6558621        William  Quispe Quispe
# 9            10  6558621  Silvana Edith Tarquino Conde
#
#                               cargo linea nestacion       fecha   hora  \
# 0  Auxiliar Operador de Estacion II  Cafe        S2  2020-11-20  08:00
# 1              Operador de Estacion  Cafe        S2  2021-01-21  16:00
# 2  Auxiliar Operador de Estacion II  Cafe        S1  2021-01-25  08:00
# 3     Auxiliar Operador de Estacion  Cafe        S1  2021-01-29  12:11
# 4              Operador de Estacion  Cafe        S2  2021-01-29  12:17
# 5              Operador de Estacion  Cafe        S2  2021-01-29  12:21
# 6              Operador de Estacion  Cafe        S2  2021-01-29  12:26
# 7  Auxiliar Operador de Estacion II  Cafe        S1  2021-01-25  12:35
# 8     Auxiliar Operador de Estacion  Cafe        S1  2021-01-29  12:50
# 9              Operador de Estacion  Cafe        S2  2021-01-29  12:53
#
#           ubicacion                                        descripcion  ...  \
# 0            Puente        Chillido en freno embrague ST lado entrada.  ...
# 1            Puente  Nivel de aceite de centralita hidraulica tren ...  ...
# 2            Puente  Nivel de liquido hidráulico por debajo de la m...  ...
# 3            Puente  No se encuentra montado el primer y ultimo neu...  ...
# 4   Sala de Control  Cuando se trabaja con generador auxiliar no se...  ...
# 5            Puente                   Cable de aguja de carga mellado.  ...
# 6            Puente  Centralita hidráulica de tren de ruedas No cue...  ...
# 7            Puente  No se soluciono el fallo continua, ruido en em...  ...
# 8            Puente  Existe leve fuga en ducto de gases del motor t...  ...
# 9  Sala de Maquinas  Faltan pernos y existen acrilicos rotos en los...  ...
#
#                           foto2  \
# 0
# 1
# 2
# 3
# 4
# 5  Cafe_2021-08-24_09:39:45.jpg
# 6
# 7
# 8
# 9  Cafe_2021-09-02_06:15:00.jpg
#
#                                               editor    fechafin  \
# 0  6558621-Jaime Gabriel Soto Gonzales 2021-06-01...  2021-05-23
# 1  4837724-Silvana Edith Tarquino Conde 2021-07-1...  2021-08-29
# 2  4837724-Silvana Edith Tarquino Conde 2021-07-1...  2021-08-29
# 3  4837724-Silvana Edith Tarquino Conde 2021-07-1...  2021-08-29
# 4  4837724-Silvana Edith Tarquino Conde 2021-07-1...  2023-10-14
# 5  4837724-Silvana Edith Tarquino Conde 2021-07-1...  2021-08-24
# 6  4837724-Silvana Edith Tarquino Conde 2021-07-1...  2021-08-29
# 7  4837724-Silvana Edith Tarquino Conde 2021-07-1...  2023-02-09
# 8  6558621-Jaime Gabriel Soto Gonzales 2021-06-02...  2021-08-29
# 9  6558621-Jaime Gabriel Soto Gonzales 2021-06-02...  2021-09-02
#
#               ip    codigo                                               VoBo  \
# 0  192.168.90.50                                    VoBo, aún no implementado
# 1  192.168.90.50                                    VoBo, aún no implementado
# 2  192.168.90.50                                    VoBo, aún no implementado
# 3  192.168.90.50                                    VoBo, aún no implementado
# 4  192.168.90.50            Verificado por: 3498915-Waldo Felix Ramirez Po...
# 5  192.168.90.50                                    VoBo, aún no implementado
# 6  192.168.90.50                                    VoBo, aún no implementado
# 7  192.168.90.50  006/2021  Verificado por: 3498915-Waldo Felix Ramirez Po...
# 8  192.168.90.50                                    VoBo, aún no implementado
# 9  192.168.90.50                                    VoBo, aún no implementado
#
#    estado2            observacion3 foto3  \
# 0  Procede
# 1  Procede
# 2  Procede
# 3  Procede
# 4  Procede  Se realiza seguimiento
# 5  Procede
# 6  Procede
# 7  Procede                006/2021
# 8  Procede
# 9  Procede
#
#                                           finalizado
# 0                                              Antes
# 1                                              Antes
# 2                                              Antes
# 3                                              Antes
# 4  Finalizado por: 6035469-Milton Egberto Bonifac...
# 5                                              Antes
# 6                                              Antes
# 7  Finalizado por: 7861185-Carlos  Chavez Mamani,...
# 8                                              Antes
# 9                                              Antes
#
# [10 rows x 28 columns]
